# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-paper')

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening(20)', 'IDA*(20)', 'A*(20)','IDA*_cheby(20)', 'A*_cheby(20)')
y_pos = np.arange(len(people))
performance = [2639,10654,55,260618,403]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 10x10', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening(18)', 'IDA*(18)', 'A*(18)','IDA*_cheby(18)', 'A*_cheby(18)')
y_pos = np.arange(len(people))
performance = [2314,29639,102,1171174,159]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 10x10 hard', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening(20)', 'IDA*(20)', 'A*(22)','IDA*_cheby(20)', 'A*_cheby(22)')
y_pos = np.arange(len(people))
performance = [1905,10413,72,85478,1993]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 10x10 test_cost', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening (not finish)', 'IDA* (no finish)', 'A*(fail)','IDA*_cheby(no finish)', 'A*_cheby(fail)')
y_pos = np.arange(len(people))
performance = [0,0,20,0,120]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 10x10 no solutions', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening(23)', 'IDA*(too long),', 'A*(23)','IDA*_cheby(too long)', 'A*_cheby(23)')
y_pos = np.arange(len(people))
performance = [3400904,0,394,0,8518]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 20x20', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening(22)', 'IDA*(22)', 'A*(24)','IDA*_cheby(22)', 'A*_cheby(24)')
y_pos = np.arange(len(people))
performance = [26484,33977532,92,33977532,4342]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(ms)', fontsize=11)
ax.set_title('Labyrinth 10x10 hard multiple', fontsize=20)

plt.show()
