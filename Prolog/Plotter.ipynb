# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-paper')

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening', 'IDA*', 'A*')
y_pos = np.arange(len(people))
performance = [2636,24403,125]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 10x10', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening', 'IDA*', 'A*')
y_pos = np.arange(len(people))
performance = [3355,60989,77]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 10x10 hard', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening', 'IDA*', 'A*')
y_pos = np.arange(len(people))
performance = [2723,26671,110]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 10x10 test_cost', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening (not finish)', 'IDA* (finish neg after 32 iterations)', 'A*')
y_pos = np.arange(len(people))
performance = [0,0,68]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 10x10 no solutions', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening', 'IDA* (not finished)', 'A*')
y_pos = np.arange(len(people))
performance = [4992882,0,316]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 20x20', fontsize=20)

plt.show()

# %%
fig, ax = plt.subplots()

# Example data
people = ('Iterative Deepening', 'IDA*(not finished)', 'A*')
y_pos = np.arange(len(people))
performance = [27907,0,170]
error = np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Time(s)', fontsize=11)
ax.set_title('Labyrinth 10x10 hard multiple', fontsize=20)

plt.show()
